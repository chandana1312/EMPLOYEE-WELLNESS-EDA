# %% [markdown]
# ## Data Loading & Checking:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import numpy as np
import pandas as pd

# %%
#employees wellness dataset

employee_df = pd.read_excel(r"C:\Users\swash\Downloads\Advanced - Employee Wellness Analysis\employee_wellness_dataset.xlsx",header = 0,index_col = 0)
employee_df
# Out:
#             Timestamp  Age  Gender         Country state self_employed  \
# S.No
# 1     8/27/2014 11:29   37  Female   United States    IL           NaN
# 2     8/27/2014 11:29   44       M   United States    IN           NaN
# 3     8/27/2014 11:29   32    Male          Canada   NaN           NaN
# 4     8/27/2014 11:29   31    Male  United Kingdom   NaN           NaN
# 5     8/27/2014 11:30   31    Male   United States    TX           NaN
# ...               ...  ...     ...             ...   ...           ...
# 1044  8/29/2014 11:20   26    Male   United States    WA            No
# 1045  8/29/2014 11:22   29       f  United Kingdom   NaN            No
# 1046  8/29/2014 11:23   26  Female          Canada   NaN            No
# 1047  8/29/2014 11:24   33    Malr           Italy   NaN            No
# 1048  8/29/2014 11:25   28    Male          Brazil   NaN            No
#
#      family_history treatment work_interfere         no_employees  ...  \
# S.No                                                               ...
# 1                No       Yes          Often  2026-06-25 00:00:00  ...
# 2                No        No         Rarely       More than 1000  ...
# 3                No        No         Rarely  2026-06-25 00:00:00  ...
# 4               Yes       Yes          Often               26-100  ...
# 5                No        No          Never              100-500  ...
# ...             ...       ...            ...                  ...  ...
# 1044             No       Yes      Sometimes  2026-06-25 00:00:00  ...
# 1045             No       Yes          Often       More than 1000  ...
# 1046            Yes       Yes      Sometimes              100-500  ...
# 1047            Yes       Yes      Sometimes  2026-06-25 00:00:00  ...
# 1048            Yes        No      Sometimes              100-500  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# S.No
# 1          Somewhat easy                        No                      No
# 2             Don't know                     Maybe                      No
# 3     Somewhat difficult                        No                      No
# 4     Somewhat difficult                       Yes                     Yes
# 5             Don't know                        No                      No
# ...                  ...                       ...                     ...
# 1044          Don't know                     Maybe                      No
# 1045          Don't know                     Maybe                      No
# 1046          Don't know                     Maybe                      No
# 1047       Somewhat easy                        No                      No
# 1048       Somewhat easy                        No                      No
#
#          coworkers    supervisor mental_health_interview  \
# S.No
# 1     Some of them           Yes                      No
# 2               No            No                      No
# 3              Yes           Yes                     Yes
# 4     Some of them            No                   Maybe
# 5     Some of them           Yes                     Yes
# ...            ...           ...                     ...
# 1044  Some of them            No                      No
# 1045  Some of them            No                      No
# 1046  Some of them            No                      No
# 1047  Some of them           Yes                      No
# 1048  Some of them  Some of them                      No
#
#      phys_health_interview mental_vs_physical obs_consequence  \
# S.No
# 1                    Maybe                Yes              No
# 2                       No         Don't know              No
# 3                      Yes                 No              No
# 4                    Maybe                 No             Yes
# 5                      Yes         Don't know              No
# ...                    ...                ...             ...
# 1044                 Maybe         Don't know              No
# 1045                   Yes                 No             Yes
# 1046                 Maybe         Don't know              No
# 1047                    No         Don't know              No
# 1048                    No         Don't know             Yes
#
#                                                comments
# S.No
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# ...                                                 ...
# 1044                                                NaN
# 1045                                                NaN
# 1046                                                NaN
# 1047  I suffered of panic attacks and agoraphobia fo...
# 1048                                                NaN
#
# [1048 rows x 27 columns]

# %% [markdown]
# ### Initial Dataset Overview
# Before any cleaning, let's look at the raw shape, structure, and a preview of the data.

# %%
employee_df.shape
# Out:
# (1048, 27)

# %%
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1048 entries, 1 to 1048
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1048 non-null   object
#  1   Age                        1048 non-null   int64
#  2   Gender                     1048 non-null   object
#  3   Country                    1048 non-null   object
#  4   state                      636 non-null    object
#  5   self_employed              1030 non-null   object
#  6   family_history             1048 non-null   object
#  7   treatment                  1048 non-null   object
#  8   work_interfere             812 non-null    object
#  9   no_employees               1048 non-null   object
#  10  remote_work                1048 non-null   object
#  11  tech_company               1048 non-null   object
#  12  benefits                   1035 non-null   object
#  13  care_options               1048 non-null   object
#  14  wellness_program           1044 non-null   object
#  15  seek_help                  1048 non-null   object
#  16  anonymity                  1048 non-null   object
#  17  leave                      1044 non-null   object
#  18  mental_health_consequence  1048 non-null   object
#  19  phys_health_consequence    1048 non-null   object
#  20  coworkers                  1048 non-null   object
#  21  supervisor                 1048 non-null   object
#  22  mental_health_interview    1048 non-null   object
#  23  phys_health_interview      1048 non-null   object
#  24  mental_vs_physical         1048 non-null   object
#  25  obs_consequence            1048 non-null   object
#  26  comments                   132 non-null    object
# dtypes: int64(1), object(26)
# memory usage: 229.2+ KB

# %%
employee_df.head()
# Out:
#             Timestamp  Age  Gender         Country state self_employed  \
# S.No
# 1     8/27/2014 11:29   37  Female   United States    IL           NaN
# 2     8/27/2014 11:29   44       M   United States    IN           NaN
# 3     8/27/2014 11:29   32    Male          Canada   NaN           NaN
# 4     8/27/2014 11:29   31    Male  United Kingdom   NaN           NaN
# 5     8/27/2014 11:30   31    Male   United States    TX           NaN
#
#      family_history treatment work_interfere         no_employees  ...  \
# S.No                                                               ...
# 1                No       Yes          Often  2026-06-25 00:00:00  ...
# 2                No        No         Rarely       More than 1000  ...
# 3                No        No         Rarely  2026-06-25 00:00:00  ...
# 4               Yes       Yes          Often               26-100  ...
# 5                No        No          Never              100-500  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# S.No
# 1          Somewhat easy                        No                      No
# 2             Don't know                     Maybe                      No
# 3     Somewhat difficult                        No                      No
# 4     Somewhat difficult                       Yes                     Yes
# 5             Don't know                        No                      No
#
#          coworkers supervisor mental_health_interview phys_health_interview  \
# S.No
# 1     Some of them        Yes                      No                 Maybe
# 2               No         No                      No                    No
# 3              Yes        Yes                     Yes                   Yes
# 4     Some of them         No                   Maybe                 Maybe
# 5     Some of them        Yes                     Yes                   Yes
#
#      mental_vs_physical obs_consequence comments
# S.No
# 1                   Yes              No      NaN
# 2            Don't know              No      NaN
# 3                    No              No      NaN
# 4                    No             Yes      NaN
# 5            Don't know              No      NaN
#
# [5 rows x 27 columns]

# %%
employee_df.tail()
# Out:
#             Timestamp  Age  Gender         Country state self_employed  \
# S.No
# 1044  8/29/2014 11:20   26    Male   United States    WA            No
# 1045  8/29/2014 11:22   29       f  United Kingdom   NaN            No
# 1046  8/29/2014 11:23   26  Female          Canada   NaN            No
# 1047  8/29/2014 11:24   33    Malr           Italy   NaN            No
# 1048  8/29/2014 11:25   28    Male          Brazil   NaN            No
#
#      family_history treatment work_interfere         no_employees  ...  \
# S.No                                                               ...
# 1044             No       Yes      Sometimes  2026-06-25 00:00:00  ...
# 1045             No       Yes          Often       More than 1000  ...
# 1046            Yes       Yes      Sometimes              100-500  ...
# 1047            Yes       Yes      Sometimes  2026-06-25 00:00:00  ...
# 1048            Yes        No      Sometimes              100-500  ...
#
#               leave mental_health_consequence phys_health_consequence  \
# S.No
# 1044     Don't know                     Maybe                      No
# 1045     Don't know                     Maybe                      No
# 1046     Don't know                     Maybe                      No
# 1047  Somewhat easy                        No                      No
# 1048  Somewhat easy                        No                      No
#
#          coworkers    supervisor mental_health_interview  \
# S.No
# 1044  Some of them            No                      No
# 1045  Some of them            No                      No
# 1046  Some of them            No                      No
# 1047  Some of them           Yes                      No
# 1048  Some of them  Some of them                      No
#
#      phys_health_interview mental_vs_physical obs_consequence  \
# S.No
# 1044                 Maybe         Don't know              No
# 1045                   Yes                 No             Yes
# 1046                 Maybe         Don't know              No
# 1047                    No         Don't know              No
# 1048                    No         Don't know             Yes
#
#                                                comments
# S.No
# 1044                                                NaN
# 1045                                                NaN
# 1046                                                NaN
# 1047  I suffered of panic attacks and agoraphobia fo...
# 1048                                                NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Checking for Duplicate Rows
# Before cleaning starts, we check how many exact duplicate rows exist in the raw data.

# %%
# Count how many duplicate rows exist

employee_df.duplicated().sum()
# Out:
# np.int64(1)

# %%
employee_df[employee_df.duplicated()]
# Out:
#             Timestamp  Age Gender         Country state self_employed  \
# S.No
# 861   8/28/2014 17:02   32   male  United Kingdom   NaN            No
#
#      family_history treatment work_interfere         no_employees  ...  \
# S.No                                                               ...
# 861             Yes       Yes         Rarely  2026-06-25 00:00:00  ...
#
#            leave mental_health_consequence phys_health_consequence  \
# S.No
# 861   Don't know                       Yes                   Maybe
#
#          coworkers supervisor mental_health_interview phys_health_interview  \
# S.No
# 861   Some of them         No                      No                    No
#
#      mental_vs_physical obs_consequence comments
# S.No
# 861                  No              No      NaN
#
# [1 rows x 27 columns]

# %% [markdown]
# ## Data Cleaning and Pre-processing-

# %% [markdown]
# **Step 1 - Removing Duplicate Rows**

# %%
# Drop duplicate rows and keep the first occurrence
# FIXED: .copy() added so later df['col'] = ... assignments don't raise SettingWithCopyWarning
employee_df = employee_df.drop_duplicates().copy()

# %%
employee_df.shape
# Out:
# (1047, 27)

# %%
employee_df.isnull().sum().sort_values(ascending = False)
# Out:
# comments                     915
# state                        411
# work_interfere               236
# self_employed                 18
# benefits                      13
# wellness_program               4
# leave                          4
# anonymity                      0
# obs_consequence                0
# mental_vs_physical             0
# phys_health_interview          0
# mental_health_interview        0
# supervisor                     0
# coworkers                      0
# phys_health_consequence        0
# mental_health_consequence      0
# Timestamp                      0
# seek_help                      0
# Age                            0
# tech_company                   0
# remote_work                    0
# no_employees                   0
# treatment                      0
# family_history                 0
# Country                        0
# Gender                         0
# care_options                   0
# dtype: int64

# %% [markdown]
# **Step 2 - Dropped Irrelevant Columns**
# 1. comments → 916/1048 are NaN (87% empty), useless at scale
# 2. state → 412 NaN (mostly non-US respondents), too sparse to use

# %%
# FIXED: reassign the result of drop(), otherwise columns are NOT actually removed
employee_df = employee_df.drop(['comments','state','Timestamp'], axis=1)
employee_df
# Out:
#       Age  Gender         Country self_employed family_history treatment  \
# S.No
# 1      37  Female   United States           NaN             No       Yes
# 2      44       M   United States           NaN             No        No
# 3      32    Male          Canada           NaN             No        No
# 4      31    Male  United Kingdom           NaN            Yes       Yes
# 5      31    Male   United States           NaN             No        No
# ...   ...     ...             ...           ...            ...       ...
# 1044   26    Male   United States            No             No       Yes
# 1045   29       f  United Kingdom            No             No       Yes
# 1046   26  Female          Canada            No            Yes       Yes
# 1047   33    Malr           Italy            No            Yes       Yes
# 1048   28    Male          Brazil            No            Yes        No
#
#      work_interfere         no_employees remote_work tech_company  ...  \
# S.No                                                               ...
# 1             Often  2026-06-25 00:00:00          No          Yes  ...
# 2            Rarely       More than 1000          No           No  ...
# 3            Rarely  2026-06-25 00:00:00          No          Yes  ...
# 4             Often               26-100          No          Yes  ...
# 5             Never              100-500         Yes          Yes  ...
# ...             ...                  ...         ...          ...  ...
# 1044      Sometimes  2026-06-25 00:00:00          No          Yes  ...
# 1045          Often       More than 1000          No           No  ...
# 1046      Sometimes              100-500          No          Yes  ...
# 1047      Sometimes  2026-06-25 00:00:00          No          Yes  ...
# 1048      Sometimes              100-500          No          Yes  ...
#
#        anonymity               leave mental_health_consequence  \
# S.No
# 1            Yes       Somewhat easy                        No
# 2     Don't know          Don't know                     Maybe
# 3     Don't know  Somewhat difficult                        No
# 4             No  Somewhat difficult                       Yes
# 5     Don't know          Don't know                        No
# ...          ...                 ...                       ...
# 1044         Yes          Don't know                     Maybe
# 1045  Don't know          Don't know                     Maybe
# 1046         Yes          Don't know                     Maybe
# 1047  Don't know       Somewhat easy                        No
# 1048  Don't know       Somewhat easy                        No
#
#      phys_health_consequence     coworkers    supervisor  \
# S.No
# 1                         No  Some of them           Yes
# 2                         No            No            No
# 3                         No           Yes           Yes
# 4                        Yes  Some of them            No
# 5                         No  Some of them           Yes
# ...                      ...           ...           ...
# 1044                      No  Some of them            No
# 1045                      No  Some of them            No
# 1046                      No  Some of them            No
# 1047                      No  Some of them           Yes
# 1048                      No  Some of them  Some of them
#
#      mental_health_interview phys_health_interview mental_vs_physical  \
# S.No
# 1                         No                 Maybe                Yes
# 2                         No                    No         Don't know
# 3                        Yes                   Yes                 No
# 4                      Maybe                 Maybe                 No
# 5                        Yes                   Yes         Don't know
# ...                      ...                   ...                ...
# 1044                      No                 Maybe         Don't know
# 1045                      No                   Yes                 No
# 1046                      No                 Maybe         Don't know
# 1047                      No                    No         Don't know
# 1048                      No                    No         Don't know
#
#      obs_consequence
# S.No
# 1                 No
# 2                 No
# 3                 No
# 4                Yes
# 5                 No
# ...              ...
# 1044              No
# 1045             Yes
# 1046              No
# 1047              No
# 1048             Yes
#
# [1047 rows x 24 columns]

# %% [markdown]
# **Step 3- Age Fixing**

# %%
employee_df['Age'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of S.No
# 1       37
# 2       44
# 3       32
# 4       31
# 5       31
#         ..
# 1044    26
# 1045    29
# 1046    26
# 1047    33
# 1048    28
# Name: Age, Length: 1047, dtype: int64>

# %%
employee_df['Age'].unique()
# Out:
# array([         37,          44,          32,          31,          33,
#                 35,          39,          42,          23,          29,
#                 36,          27,          46,          41,          34,
#                 30,          40,          38,          50,          24,
#                 18,          28,          26,          22,          19,
#                 25,          45,          21,         -29,          43,
#                 56,          60,          54,         329,          55,
#        99999999999,          48,          20,          57,          58,
#                 47,          62,          51,          65,          49,
#              -1726,           5,          53,          61,           8])

# %%
employee_df['Age'].describe()
# Out:
# count    1.047000e+03
# mean     9.551101e+07
# std      3.090485e+09
# min     -1.726000e+03
# 25%      2.700000e+01
# 50%      3.100000e+01
# 75%      3.600000e+01
# max      1.000000e+11
# Name: Age, dtype: float64

# %%
employee_df.loc[:, 'Age'] = pd.to_numeric(employee_df['Age'], errors='coerce')
#(Converts the Age column into numeric values.
#Any invalid entries (like text "NA", "abc") are turned into NaN (missing values).
#Using .loc[:, 'Age'] avoids the SettingWithCopyWarning.)

# Mark unrealistic ages (below 18 or above 100) as NaN instead of dropping the row
employee_df.loc[(employee_df['Age'] < 18) | (employee_df['Age'] > 100), 'Age'] = pd.NA
employee_df.loc[:, 'Age'] = pd.to_numeric(employee_df['Age'], errors='coerce')
#Marks impossible ages as missing rather than deleting the whole row/person.
#This preserves row count while still removing bad values.

employee_df.loc[:, 'Age'] = employee_df['Age'].fillna(employee_df['Age'].median())
#Fills missing ages (NaN) with the median age of the dataset.
#Median is chosen because it's less affected by outliers compared to the mean.

# %% [markdown]
# 1. Mean (average): Adds up all ages and divides by the count.
# Problem: If there are unrealistic ages (like 200 or 5), the mean gets pulled up or down unfairly.
# 2. Median (middle value): Finds the middle age when sorted.
# Advantage: It’s robust to outliers. Even if a few extreme ages exist, the median stays stable.

# %%
employee_df['Age'].describe()
# Out:
# count    1047.000000
# mean       31.915950
# std         7.198802
# min        18.000000
# 25%        27.000000
# 50%        31.000000
# 75%        36.000000
# max        65.000000
# Name: Age, dtype: float64

# %%
employee_df['Age'].value_counts(dropna=False)
# Out:
# Age
# 29.0    73
# 26.0    63
# 32.0    63
# 31.0    63
# 33.0    63
# 27.0    61
# 28.0    56
# 30.0    56
# 34.0    52
# 35.0    49
# 25.0    48
# 23.0    41
# 24.0    38
# 37.0    36
# 36.0    31
# 38.0    30
# 39.0    26
# 40.0    26
# 43.0    23
# 22.0    20
# 42.0    17
# 41.0    15
# 21.0    15
# 45.0     9
# 19.0     9
# 44.0     8
# 18.0     7
# 46.0     7
# 50.0     5
# 48.0     5
# 20.0     4
# 49.0     4
# 51.0     4
# 57.0     3
# 56.0     3
# 55.0     3
# 54.0     3
# 47.0     2
# 58.0     1
# 62.0     1
# 65.0     1
# 60.0     1
# 53.0     1
# 61.0     1
# Name: count, dtype: int64

# %% [markdown]
# **Step 4 - Cleaning Gender column**

# %%
employee_df['Gender'].unique()
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr'], dtype=object)

# %%
def clean_gender(g):
    g = str(g).strip().lower()

    male_terms = ['male', 'm', 'mal', 'male-ish', 'maile', 'mail', 'malr',
                  'cis male', 'cis man', 'male (cis)', 'guy (-ish) ^_^',
                  'male leaning androgynous', 'something kinda male?',
                  'man', 'msle', 'make']

    female_terms = ['female', 'f', 'femake', 'cis female', 'cis-female/femme',
                     'female (cis)', 'woman', 'femail']

    other_terms = ['trans-female', 'trans woman', 'female (trans)', 'queer',
                    'queer/shae/they', 'non-binary', 'genderqueer', 'androgyne',
                    'agender', 'enby', 'fluid', 'neuter']

    if g in male_terms:
        return 'Male'
    elif g in female_terms:
        return 'Female'
    else:
        return 'Other'   # catches stray junk answers like 'Nah', 'All', 'A little about you'

employee_df['Gender_clean'] = employee_df['Gender'].apply(clean_gender)
employee_df['Gender_clean'].value_counts()
# Out:
# Gender_clean
# Male      829
# Female    202
# Other      16
# Name: count, dtype: int64

# %%
employee_df['Gender_clean'].value_counts(dropna=False)
# Out:
# Gender_clean
# Male      829
# Female    202
# Other      16
# Name: count, dtype: int64

# %%
employee_df['Gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df.shape
# Out:
# (1047, 25)

# %% [markdown]
# **Step 5 - Self Employed Column**

# %%
employee_df.loc[:,'self_employed'] = employee_df['self_employed'].fillna('No')

# %%
employee_df['self_employed'].value_counts(dropna=False)
# Out:
# self_employed
# No     923
# Yes    124
# Name: count, dtype: int64

# %%
employee_df
# Out:
#        Age  Gender         Country self_employed family_history treatment  \
# S.No
# 1     37.0  Female   United States            No             No       Yes
# 2     44.0       M   United States            No             No        No
# 3     32.0    Male          Canada            No             No        No
# 4     31.0    Male  United Kingdom            No            Yes       Yes
# 5     31.0    Male   United States            No             No        No
# ...    ...     ...             ...           ...            ...       ...
# 1044  26.0    Male   United States            No             No       Yes
# 1045  29.0       f  United Kingdom            No             No       Yes
# 1046  26.0  Female          Canada            No            Yes       Yes
# 1047  33.0    Malr           Italy            No            Yes       Yes
# 1048  28.0    Male          Brazil            No            Yes        No
#
#      work_interfere         no_employees remote_work tech_company  ...  \
# S.No                                                               ...
# 1             Often  2026-06-25 00:00:00          No          Yes  ...
# 2            Rarely       More than 1000          No           No  ...
# 3            Rarely  2026-06-25 00:00:00          No          Yes  ...
# 4             Often               26-100          No          Yes  ...
# 5             Never              100-500         Yes          Yes  ...
# ...             ...                  ...         ...          ...  ...
# 1044      Sometimes  2026-06-25 00:00:00          No          Yes  ...
# 1045          Often       More than 1000          No           No  ...
# 1046      Sometimes              100-500          No          Yes  ...
# 1047      Sometimes  2026-06-25 00:00:00          No          Yes  ...
# 1048      Sometimes              100-500          No          Yes  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# S.No
# 1          Somewhat easy                        No                      No
# 2             Don't know                     Maybe                      No
# 3     Somewhat difficult                        No                      No
# 4     Somewhat difficult                       Yes                     Yes
# 5             Don't know                        No                      No
# ...                  ...                       ...                     ...
# 1044          Don't know                     Maybe                      No
# 1045          Don't know                     Maybe                      No
# 1046          Don't know                     Maybe                      No
# 1047       Somewhat easy                        No                      No
# 1048       Somewhat easy                        No                      No
#
#          coworkers    supervisor mental_health_interview  \
# S.No
# 1     Some of them           Yes                      No
# 2               No            No                      No
# 3              Yes           Yes                     Yes
# 4     Some of them            No                   Maybe
# 5     Some of them           Yes                     Yes
# ...            ...           ...                     ...
# 1044  Some of them            No                      No
# 1045  Some of them            No                      No
# 1046  Some of them            No                      No
# 1047  Some of them           Yes                      No
# 1048  Some of them  Some of them                      No
#
#      phys_health_interview mental_vs_physical obs_consequence Gender_clean
# S.No
# 1                    Maybe                Yes              No       Female
# 2                       No         Don't know              No         Male
# 3                      Yes                 No              No         Male
# 4                    Maybe                 No             Yes         Male
# 5                      Yes         Don't know              No         Male
# ...                    ...                ...             ...          ...
# 1044                 Maybe         Don't know              No         Male
# 1045                   Yes                 No             Yes       Female
# 1046                 Maybe         Don't know              No       Female
# 1047                    No         Don't know              No         Male
# 1048                    No         Don't know             Yes         Male
#
# [1047 rows x 25 columns]

# %% [markdown]
# **Step 6 - Treatment column & Family History column**

# %%
employee_df['treatment'].value_counts()
# Out:
# treatment
# No     536
# Yes    511
# Name: count, dtype: int64

# %%
employee_df['family_history'].value_counts()
# Out:
# family_history
# No     643
# Yes    404
# Name: count, dtype: int64

# %% [markdown]
# **Step 7 - work_interfere (236 null values)**

# %%
employee_df['work_interfere'].value_counts()
# Out:
# work_interfere
# Sometimes    386
# Never        178
# Rarely       143
# Often        104
# Name: count, dtype: int64

# %%
employee_df['work_interfere'].isnull().sum()
# Out:
# np.int64(236)

# %%
# FIXED: was employee_df.loc['work_interfere'] (a ROW label, adds a junk row).
# Correct way to fill nulls in the work_interfere COLUMN:
employee_df['work_interfere'] = employee_df['work_interfere'].fillna('Not applicable')

# %%
employee_df['work_interfere'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Step 8 - No employees column**

# %%
employee_df['no_employees'].value_counts()
# Out:
# no_employees
# 2026-06-25 00:00:00    244
# 26-100                 238
# More than 1000         227
# 100-500                150
# 2026-01-05 00:00:00    133
# 500-1000                55
# Name: count, dtype: int64

# %%
employee_df['no_employees'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['no_employees'].mode()
# Out:
# 0    2026-06-25 00:00:00
# Name: no_employees, dtype: object

# %%
employee_df['no_employees'] = employee_df['no_employees'].replace({
    pd.Timestamp('2026-06-25'): '6-25',
    pd.Timestamp('2026-01-05'): '1-5'
})

# %%
employee_df['no_employees'] = employee_df['no_employees'].fillna(
    employee_df['no_employees'].mode()[0]
)

# %% [markdown]
# 1. Mean - Numeric only - Continuous data, no major outliers (e.g. Age)
# 2. Median - Numeric only - Continuous data with outliers or skew (e.g. Age given the outliers you saw earlier)
# 3. Mode - Numeric or categorical - Any categorical/text column, or numeric columns where the most common value is what matters (e.g. no_employees,Gender, benefits)

# %%
employee_df['no_employees'].value_counts()
# Out:
# no_employees
# 6-25              244
# 26-100            238
# More than 1000    227
# 100-500           150
# 1-5               133
# 500-1000           55
# Name: count, dtype: int64

# %%
employee_df['no_employees'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'self_employed', 'family_history',
#        'treatment', 'work_interfere', 'no_employees', 'remote_work',
#        'tech_company', 'benefits', 'care_options', 'wellness_program',
#        'seek_help', 'anonymity', 'leave', 'mental_health_consequence',
#        'phys_health_consequence', 'coworkers', 'supervisor',
#        'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'Gender_clean'],
#       dtype='object')

# %% [markdown]
# **Step 9 - Country , Benefits , Tech Company and Remote Work column**

# %% [markdown]
# **Column: Country**

# %%
employee_df['Country'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['Country'] = employee_df['Country'].fillna(
    employee_df['Country'].mode()[0]
)

# %% [markdown]
# **Column: Country**

# %%
employee_df['Country'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Column: Benefits**

# %%
employee_df['benefits'].isnull().sum()
# Out:
# np.int64(13)

# %%
employee_df['benefits'].mode()
# Out:
# 0    Yes
# Name: benefits, dtype: object

# %%
employee_df['benefits'].value_counts()
# Out:
# benefits
# Yes           400
# Don't know    329
# No            305
# Name: count, dtype: int64

# %%
employee_df['benefits'] = employee_df['benefits'].fillna(
    employee_df['benefits'].mode()[0])

# %% [markdown]
# **Column: Benefits**

# %%
employee_df['benefits'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Column: Tech Company**

# %%
employee_df['tech_company'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['tech_company'].value_counts()
# Out:
# tech_company
# Yes    870
# No     177
# Name: count, dtype: int64

# %%
employee_df['tech_company'] = employee_df['tech_company'].fillna(
    employee_df['tech_company'].mode()[0])

# %% [markdown]
# **Column: Tech Company**

# %%
employee_df['tech_company'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Column: Remote Work**

# %%
employee_df['remote_work'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['remote_work'].value_counts()
# Out:
# remote_work
# No     732
# Yes    315
# Name: count, dtype: int64

# %%
employee_df['remote_work'] = employee_df['remote_work'].fillna(
    employee_df['remote_work'].mode()[0])

# %% [markdown]
# **Column: Remote Work**

# %%
employee_df['remote_work'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Step 10 - Care Options , Wellness Program , Seek help , Anonymity**

# %% [markdown]
# **Column: Care Options**

# %%
employee_df['care_options'].value_counts()
# Out:
# care_options
# No          421
# Yes         363
# Not sure    263
# Name: count, dtype: int64

# %%
employee_df['care_options'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['care_options'] = employee_df['care_options'].fillna(
    employee_df['care_options'].mode()[0]
)

# %%
employee_df['care_options'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Column: Wellness Program**

# %%
employee_df['wellness_program'].value_counts()
# Out:
# wellness_program
# No            691
# Yes           193
# Don't know    159
# Name: count, dtype: int64

# %%
employee_df['wellness_program'].isnull().sum()
# Out:
# np.int64(4)

# %%
employee_df['wellness_program'] = employee_df['wellness_program'].fillna(
    employee_df['wellness_program'].mode()[0]
)

# %%
employee_df['wellness_program'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Column: Seek Help**

# %%
employee_df['seek_help'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['seek_help'].value_counts()
# Out:
# seek_help
# No            533
# Don't know    309
# Yes           205
# Name: count, dtype: int64

# %%
employee_df['seek_help'] = employee_df['seek_help'].fillna(
    employee_df['seek_help'].mode()[0]
)

# %%
employee_df['seek_help'].value_counts()
# Out:
# seek_help
# No            533
# Don't know    309
# Yes           205
# Name: count, dtype: int64

# %% [markdown]
# **Column: Anonymity**

# %%
employee_df['anonymity'].value_counts()
# Out:
# anonymity
# Don't know    685
# Yes           311
# No             51
# Name: count, dtype: int64

# %%
employee_df['anonymity'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['anonymity'] = employee_df['anonymity'].fillna(
    employee_df['anonymity'].mode()[0]
)

# %% [markdown]
# **Column: Anonymity**

# %%
employee_df['anonymity'].value_counts()
# Out:
# anonymity
# Don't know    685
# Yes           311
# No             51
# Name: count, dtype: int64

# %% [markdown]
# **Step 11 - Leave , Mental Health Consequences , Phys Health Consequences , Coworkers**

# %% [markdown]
# **Column: Leave**

# %%
employee_df['leave'].value_counts()
# Out:
# leave
# Don't know            461
# Somewhat easy         218
# Very easy             176
# Somewhat difficult    107
# Very difficult         81
# Name: count, dtype: int64

# %%
employee_df['leave'].isnull().sum()
# Out:
# np.int64(4)

# %%
employee_df['leave'] = employee_df['leave'].fillna("Don't know")

# %%
employee_df['leave'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Column: Mental Health Consequence**

# %%
employee_df['mental_health_consequence'].value_counts()
# Out:
# mental_health_consequence
# No       424
# Maybe    380
# Yes      243
# Name: count, dtype: int64

# %%
employee_df['mental_health_consequence'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['mental_health_consequence'] = employee_df['mental_health_consequence'].fillna(
    employee_df['mental_health_consequence'].mode()[0]
)

# %%
employee_df['mental_health_consequence'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Column: Physical Health Consequence**

# %%
employee_df['phys_health_consequence'].value_counts()
# Out:
# phys_health_consequence
# No       773
# Maybe    226
# Yes       48
# Name: count, dtype: int64

# %%
employee_df['phys_health_consequence'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['phys_health_consequence'] = employee_df['phys_health_consequence'].fillna(
    employee_df['phys_health_consequence'].mode()[0]
)

# %%
employee_df['phys_health_consequence'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Column: Coworkers**

# %%
employee_df['coworkers'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['coworkers'].value_counts()
# Out:
# coworkers
# Some of them    650
# No              209
# Yes             188
# Name: count, dtype: int64

# %%
employee_df['coworkers'] = employee_df['coworkers'].fillna(
    employee_df['coworkers'].mode()[0]
)

# %% [markdown]
# **Column: Coworkers**

# %%
employee_df['coworkers'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Column: Supervisor**

# %%
employee_df['supervisor'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['supervisor'] = employee_df['supervisor'].fillna(
    employee_df['supervisor'].mode()[0]

)

# %%
employee_df['supervisor'].value_counts()
# Out:
# supervisor
# Yes             439
# No              319
# Some of them    289
# Name: count, dtype: int64

# %% [markdown]
# **Column: Mental Health Interview**

# %%
employee_df['mental_health_interview'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['mental_health_interview'] = employee_df['mental_health_interview'].fillna(
    employee_df['mental_health_interview'].mode()[0])

# %%
employee_df['mental_health_interview'].value_counts()
# Out:
# mental_health_interview
# No       834
# Maybe    177
# Yes       36
# Name: count, dtype: int64

# %% [markdown]
# **Column: Physical Health Interview**

# %%
employee_df['phys_health_interview'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['phys_health_interview'] = employee_df['phys_health_interview'].fillna(
    employee_df['phys_health_interview'].mode()[0])

# %%
employee_df['phys_health_interview'].value_counts()
# Out:
# phys_health_interview
# Maybe    461
# No       418
# Yes      168
# Name: count, dtype: int64

# %% [markdown]
# **Column: Mental vs Physical**

# %%
employee_df['mental_vs_physical'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['mental_vs_physical'] = employee_df['mental_vs_physical'].fillna(
    employee_df['mental_vs_physical'].mode()[0])

# %%
employee_df['mental_vs_physical'].value_counts()
# Out:
# mental_vs_physical
# Don't know    471
# Yes           297
# No            279
# Name: count, dtype: int64

# %% [markdown]
# **Column: Mental vs Physical**

# %%
employee_df['mental_vs_physical'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Column: Observed Consequence**

# %%
employee_df['obs_consequence'].isnull().sum()
# Out:
# np.int64(0)

# %%
employee_df['obs_consequence'] = employee_df['obs_consequence'].fillna(
    employee_df['obs_consequence'].mode()[0])

# %%
employee_df['obs_consequence'].value_counts()
# Out:
# obs_consequence
# No     901
# Yes    146
# Name: count, dtype: int64

# %% [markdown]
# ### Final Cleaned Dataset Shape
# Confirming the dataset is fully cleaned and still holds all original (non-duplicate) rows.

# %%
employee_df.shape
# Out:
# (1047, 25)

# %% [markdown]
# ## Fix Log (applied to this notebook)
#
# 3 bugs were found and corrected so the pipeline reliably ends at **1047 rows**:
#
# 1. **`drop()` not reassigned** — `comments`, `state`, `Timestamp` were never actually removed. Fixed by reassigning `employee_df = employee_df.drop(...)`.
# 2. **`.loc['work_interfere']` row-label bug** — was appending a junk row instead of filling nulls in the `work_interfere` column. Fixed to `employee_df['work_interfere'] = employee_df['work_interfere'].fillna('Not applicable')`.
# 3. **Missing `.copy()` after `drop_duplicates()`** — was causing `SettingWithCopyWarning` on every later assignment. Fixed by chaining `.copy()`.
#
# **Before presenting/submitting: `Kernel → Restart & Run All` from top to bottom, in order, and confirm `employee_df.shape` reads `(1047, 24)` at the end of the cleaning section.** All outputs in this file were cleared so the notebook is fully reproducible — no stale/out-of-order results.

# %% [markdown]
# # EDA — Storytelling Charts (Univariate → Bivariate → Multivariate)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", palette="Set2")
plt.rcParams['figure.dpi'] = 110

print(employee_df.shape)   # sanity check -> should read (1047, 24)
# Out:
# (1047, 25)

# %% [markdown]
# ## Chart 1 — Age Distribution
#
# **What does the age profile of our respondents look like, and why does it matter before we discuss mental health at work?**
#
# **Type:** Histogram + KDE | **Variate:** Univariate (numeric)

# %%
plt.figure(figsize=(8,5))
sns.histplot(employee_df['Age'], bins=20, kde=True, color="#4C72B0")
plt.axvline(employee_df['Age'].median(), color='red', linestyle='--',
            label=f"Median = {employee_df['Age'].median():.0f}")
plt.title("Age Distribution of Survey Respondents", fontsize=13, weight='bold')
plt.xlabel("Age"); plt.ylabel("Number of Employees")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **📌 Inference:** Right-skewed distribution concentrated between 25–36, median ≈ 31 — a young, early/mid-career workforce.

# %% [markdown]
# ## Chart 2 — Gender Split
#
# **What does the gender composition of our sample look like, and why do we need to know this before slicing later charts by gender?**
#
# **Type:** Donut chart | **Variate:** Univariate (categorical)

# %%
gender_counts = employee_df['Gender_clean'].value_counts()

plt.figure(figsize=(6,6))
colors = ['#4C72B0', '#DD8452', '#55A868']
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%',
        startangle=90, colors=colors, wedgeprops={'width':0.4, 'edgecolor':'white'})
plt.title("Gender Distribution", fontsize=13, weight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Inference:** Sample is heavily male-skewed (~79% Male, ~19% Female, ~1% Others) — flag as a sample-size limitation for any later gender comparison.

# %% [markdown]
# ## Chart 3 — Family History vs Seeking Treatment  (Chandana)
#
#
# **Does having a family history of mental illness change how likely someone is to seek treatment?**
#
# **Type:** Grouped bar chart from a crosstab | **Variate:** Bivariate (categorical × categorical)

# %%
ct = pd.crosstab(employee_df['family_history'], employee_df['treatment'], normalize='index') * 100
display(ct.round(1))

ax = ct.plot(kind='bar', stacked=False, figsize=(7,5), color=['#C44E52','#55A868'])
plt.title("Does Family History Predict Seeking Treatment?", fontsize=13, weight='bold')
plt.xlabel("Family History of Mental Illness"); plt.ylabel("% of Group")
plt.xticks(rotation=0)
plt.legend(title="Sought Treatment")
for c in ax.containers:
    ax.bar_label(c, fmt='%.1f%%')
plt.tight_layout()
plt.show()
# Out:
# treatment         No   Yes
# family_history
# No              66.4  33.6
# Yes             27.0  73.0

# %% [markdown]
# **Inference:** Print the crosstab % below and quote it live — expect respondents *with* a family history to seek treatment at a noticeably higher rate.

# %% [markdown]
# ## Chart 4 — Work Interference vs Treatment, split by Gender (Tanishka)
#
# **How often does work interfere with mental health, and does that pattern differ by gender?**
#
# **Type:** Countplot with `hue` | **Variate:** Multivariate (3 variables)

# %%
plt.figure(figsize=(9,5))
sns.countplot(x='work_interfere', hue='Gender_clean', data=employee_df,
              order=['Never','Rarely','Sometimes','Often','Not applicable'],
              palette="Set2")
plt.title("Work Interference with Mental Health, by Gender", fontsize=13, weight='bold')
plt.xlabel("How Often Work Interferes with Mental Health"); plt.ylabel("Count")
plt.legend(title="Gender")
plt.tight_layout()
plt.show()

# supporting crosstab for the exact % to quote on stage
display((pd.crosstab(employee_df['work_interfere'], employee_df['treatment'], normalize='index') * 100).round(1))
# Out:
# treatment         No   Yes
# work_interfere
# Never           86.0  14.0
# Not applicable  99.2   0.8
# Often           16.3  83.7
# Rarely          27.3  72.7
# Sometimes       24.1  75.9

# %% [markdown]
# **Inference:** Most interference is "Sometimes," not "Often" — a background, everyday strain rather than a rare crisis.

# %% [markdown]
# ## Chart 5 — Corelation Heatmap of Selected variables (Swara)
# **Is there any relationship (correlation) between age and different workplace or mental health factors in the employee dataset?**
#
# **Type:** Heatmap | **Variate:** Multi-variate(both numerical and categorical)

# %%
# Convert binary variables to numerical values

corr_df = employee_df[['Age', 'treatment', 'family_history',
              'self_employed', 'remote_work',
              'tech_company', 'obs_consequence']].copy()

binary_cols = ['treatment', 'family_history', 'self_employed',
               'remote_work', 'tech_company', 'obs_consequence']

for col in binary_cols:
    corr_df[col] = corr_df[col].map({'Yes': 1, 'No': 0})

# Correlation matrix
corr_matrix = corr_df.corr().round(2)

# Heatmap
plt.figure(figsize=(9,7))

sns.heatmap(
    corr_matrix,
    annot=True,
    fmt='.2f',
    cmap='Greens',
    center=0
)

plt.title('Correlation Heatmap of Selected Variables')
plt.show()

# %% [markdown]
# **Inference:**
#
# 1. 0.55 → Employees with a family history are more likely to seek treatment.
# 2. 0.10 → Remote work has almost no relationship with treatment.
# 3. -0.05 → Age has almost no relationship with treatment.
#
# Remember: Correlation does not mean causation.
#
# If family_history and treatment have a correlation of 0.55, it does not prove that family history causes someone to seek treatment. It only shows that the two variables tend to change together.

# %% [markdown]
# ## Conclusion:
